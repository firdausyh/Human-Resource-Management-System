# %%
import pandas as pd
#file_1= pd.read_csv('C:\\Users\\Firdausy\\Desktop\\Training\\DS\\Datasets\\energy.csv', error_bad_lines=False)
Country= pd.read_csv('C:\\Users\\Firdausy\\Desktop\\Training\\BI\\Country.txt', delimiter = '\\t')
State= pd.read_csv('C:\\Users\\Firdausy\\Desktop\\Training\\BI\\State.txt', delimiter = '\\t')
City= pd.read_csv('C:\\Users\\Firdausy\\Desktop\\Training\\BI\\city.txt', delimiter = '\\t')
Designation= pd.read_csv('C:\\Users\\Firdausy\\Desktop\\Training\\BI\\Designation.txt', delimiter = '\\t')
Employee_Details= pd.read_csv('C:\\Users\\Firdausy\\Desktop\\Training\\BI\\Emp_deets.txt', delimiter = '\\t')
Salary= pd.read_csv('C:\\Users\\Firdausy\\Desktop\\Training\\BI\\Salary.txt', delimiter = '\\t')

# %%
Q1
Join_1 = pd.merge((pd.merge((pd.merge((pd.merge(Employee_Details, Country, how = 'left', left_on='Emp_Country_Id', right_on = 'Country_Id')),State, how = 'left', left_on='Emp_State_Id', right_on = 'State_Id')),
                                      City, how = 'left', left_on='Emp_City_Id', right_on = 'City_Id')),
                                      Designation, how = 'left', left_on='Design_Id', right_on = 'Design_Id')

Join_1.loc[:, ['Emp_First_Name', 'Emp_Last_Name', 'Emp_Middle_Name', 'Country_Name', 'State_Name', 'City_Name', 'Emp_Mobile', 'Design_Name']]
# Out:
#   Emp_First_Name Emp_Last_Name Emp_Middle_Name Country_Name        State_Name  \
# 0        Ronaldo     Fabrizzio            Rome      Albania             Adrar
# 1         Joshua           Kan             NaN      Denmark           Hawalli
# 2        Yuriana      Hagasawa             NaN        China           Capital
# 3        Venessa      Katarina         Cameron      Denmark             Crete
# 4           Sahi          King             NaN      Denmark  Eastern District
# 5           Chen          Chen             NaN      Andorra            Tipaza
# 6          Ricky     Riverland          Russel      Denmark  Eastern District
#
#    City_Name  Emp_Mobile  Design_Name
# 0      Berat  1317778395          NaN
# 1        NaN  8553432022          NaN
# 2  Rochester  6644227722          NaN
# 3        NaN  8572222210          NaN
# 4        NaN  6173338992          NaN
# 5    Amsthas  1988883321          NaN
# 6        NaN  8572223333          NaN

# %%
Q2
St_Ct = pd.merge(State, Country, how = 'outer', left_on = 'Country_Id', right_on = 'Country_Id')
(St_Ct.loc[:,['State_Name', 'Country_Name']]).sort_values(by = 'State_Name', ascending = True)
# Out:
#           State_Name   Country_Name
# 51              Abim         Uganda
# 6              Adrar        Algeria
# 26            Ajaria        Georgia
# 32             Akita          Japan
# 40          Al Khawr          Qatar
# 46            Alaska  United States
# 41             Altay         Russia
# 19           Atacama          Chile
# 53              Ataq          Yemen
# 23          Auvergne         France
# 52           Bac Can        Vietnam
# 0         Badakhshan    Afghanistan
# 1            Badghis    Afghanistan
# 2            Baghlan    Afghanistan
# 15             Bahia         Brazil
# 29      BaranyaMegye        Hungary
# 3              Berat        Albania
# 43              Bern    Switzerland
# 7              Blida        Algeria
# 25            Bremen        Germany
# 54          Bulawayo       Zimbabwe
# 13        Burgenland        Austria
# 49        California  United States
# 9            Canillo        Andorra
# 20           Capital        Denmark
# ...

# %%
Q3
(Country.sort_values(by = 'Country_Name', ascending = True)).head(3)
# Out:
#    Country_Id Country_Name
# 0           1  Afghanistan
# 1           2      Albania
# 2           3      Algeria

# %%
Q4
Employee_Details[Employee_Details.Emp_First_Name.str.startswith('a')]
# Out:
# Empty DataFrame
# Columns: [Emp_Id, Emp_First_Name, Emp_Middle_Name, Emp_Last_Name, Emp_Address1, Emp_Address2, Emp_Country_Id, Emp_State_Id, Emp_City_Id, Emp_Zip, Emp_Mobile, Emp_Gender, Design_Id, Emp_DOB, Emp_JoinDate, Emp_Active]
# Index: []

# %%
Q5
Employee_Details[Employee_Details.Emp_First_Name.str.endswith('a')]
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 1       2         Joshua             NaN           Kan
# 2       3        Yuriana             NaN      Hagasawa
# 3       4        Venessa         Cameron      Katarina
#
#                 Emp_Address1 Emp_Address2  Emp_Country_Id  Emp_State_Id  \
# 1           533 Kosher Drive          NaN              11            34
# 2             122 Kobeya Ave          NaN               9            21
# 3  1001 Michigan Ave Apt3201          NaN              11            28
#
#    Emp_City_Id  Emp_Zip  Emp_Mobile  Emp_Gender  Design_Id  \
# 1           54     3115  8553432022           1          2
# 2           27    84430  6644227722           0          1
# 3           38     1101  8572222210           0          6
#
#                    Emp_DOB             Emp_JoinDate  Emp_Active
# 1  1986-08-01 00:00:00.000  2010-01-27 00:00:00.000           1
# 2  1988-12-13 00:00:00.000  2013-09-01 00:00:00.000           0
# ...

# %%
Q6
Employee_Details[Employee_Details.Emp_Active == 0]
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name    Emp_Address1  \
# 2       3        Yuriana             NaN      Hagasawa  122 Kobeya Ave
#
#   Emp_Address2  Emp_Country_Id  Emp_State_Id  Emp_City_Id  Emp_Zip  \
# 2          NaN               9            21           27    84430
#
#    Emp_Mobile  Emp_Gender  Design_Id                  Emp_DOB  \
# 2  6644227722           0          1  1988-12-13 00:00:00.000
#
#               Emp_JoinDate  Emp_Active
# 2  2013-09-01 00:00:00.000           0

# %%
Q7

# %%
Q8
(Employee_Details.Emp_Id).count()
# Out:
# 7

# %%
Q9
Employee_Details[Employee_Details.Emp_Middle_Name.notnull()]
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 0       1        Ronaldo            Rome     Fabrizzio
# 3       4        Venessa         Cameron      Katarina
# 6   10002          Ricky          Russel     Riverland
#
#                    Emp_Address1 Emp_Address2  Emp_Country_Id  Emp_State_Id  \
# 0               75 Calle Suerte          NaN               2             7
# 3     1001 Michigan Ave Apt3201          NaN              11            28
# 6  1019 Commonwealth Ave Apt301          NaN              11            29
#
#    Emp_City_Id  Emp_Zip  Emp_Mobile  Emp_Gender  Design_Id  \
# 0            4    10034  1317778395           1          4
# 3           38     1101  8572222210           0          6
# 6           39     2215  8572223333           1          3
#
#                    Emp_DOB             Emp_JoinDate  Emp_Active
# 0  1978-05-12 00:00:00.000  2012-03-22 00:00:00.000           1
# 3  1987-11-01 00:00:00.000  2009-02-01 00:00:00.000           1
# ...

# %%
Q10
Employee_Details.loc[Employee_Details['Emp_Middle_Name'].isnull(), 'Emp_Middle_Name'] = 'Not Applicable'

# %%
Q11
Fn = Employee_Details.Emp_First_Name
Ln = Employee_Details.Emp_Last_Name
Mn = Employee_Details.Emp_Middle_Name
print(pd.concat([Fn, Ln, Mn], axis = 1))
# Out:
#   Emp_First_Name Emp_Last_Name Emp_Middle_Name
# 0        Ronaldo     Fabrizzio            Rome
# 1         Joshua           Kan  Not Applicable
# 2        Yuriana      Hagasawa  Not Applicable
# 3        Venessa      Katarina         Cameron
# 4           Sahi          King  Not Applicable
# 5           Chen          Chen  Not Applicable
# 6          Ricky     Riverland          Russel

# %%
Q12
(pd.merge(Employee_Details, Country, left_on = 'Emp_Country_Id', right_on = 'Country_Id')).sort_values(
    by = 'Country_Name', ascending = True)
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 0       1        Ronaldo            Rome     Fabrizzio
# 6       6           Chen  Not Applicable          Chen
# 5       3        Yuriana  Not Applicable      Hagasawa
# 1       2         Joshua  Not Applicable           Kan
# 2       4        Venessa         Cameron      Katarina
# 3       5           Sahi  Not Applicable          King
# 4   10002          Ricky          Russel     Riverland
#
#                    Emp_Address1                 Emp_Address2  Emp_Country_Id  \
# 0               75 Calle Suerte                          NaN               2
# 6       55 Beijing Road Apt1501  230 Sanjiangkou Road Apt202               4
# 5                122 Kobeya Ave                          NaN               9
# 1              533 Kosher Drive                          NaN              11
# 2     1001 Michigan Ave Apt3201                          NaN              11
# ...

# %%
Q13
Employee_Details[0:10].sort_values(by = 'Emp_First_Name', ascending = True)
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 5       6           Chen  Not Applicable          Chen
# 1       2         Joshua  Not Applicable           Kan
# 6   10002          Ricky          Russel     Riverland
# 0       1        Ronaldo            Rome     Fabrizzio
# 4       5           Sahi  Not Applicable          King
# 3       4        Venessa         Cameron      Katarina
# 2       3        Yuriana  Not Applicable      Hagasawa
#
#                    Emp_Address1                 Emp_Address2  Emp_Country_Id  \
# 5       55 Beijing Road Apt1501  230 Sanjiangkou Road Apt202               4
# 1              533 Kosher Drive                          NaN              11
# 6  1019 Commonwealth Ave Apt301                          NaN              11
# 0               75 Calle Suerte                          NaN               2
# 4          15 Gibbs Street Apt1                          NaN              11
# ...

# %%
Q14
Em_Cy = pd.merge(Employee_Details, City, how = 'left', left_on = 'Emp_City_Id',
          right_on = 'City_Id')

Em_Cy[(Em_Cy.City_Name == 'Dallas')|(Em_Cy.City_Name == 'Algiers')]
# Out:
# Empty DataFrame
# Columns: [Emp_Id, Emp_First_Name, Emp_Middle_Name, Emp_Last_Name, Emp_Address1, Emp_Address2, Emp_Country_Id, Emp_State_Id, Emp_City_Id, Emp_Zip, Emp_Mobile, Emp_Gender, Design_Id, Emp_DOB, Emp_JoinDate, Emp_Active, City_Id, State_Id, City_Name]
# Index: []

# %%
Q15
Em_Cy = pd.merge(Employee_Details, City, left_on = 'Emp_City_Id',
          right_on = 'City_Id')
Em_Cy[Em_Cy.City_Name.str.startswith('A')|Em_Cy.City_Name.str.startswith('B')|Em_Cy.City_Name.str.startswith('C')|Em_Cy.City_Name.str.startswith('D')]
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 0       1        Ronaldo            Rome     Fabrizzio
# 2       6           Chen             NaN          Chen
#
#               Emp_Address1                 Emp_Address2  Emp_Country_Id  \
# 0          75 Calle Suerte                          NaN               2
# 2  55 Beijing Road Apt1501  230 Sanjiangkou Road Apt202               4
#
#    Emp_State_Id  Emp_City_Id  Emp_Zip  Emp_Mobile  Emp_Gender  Design_Id  \
# 0             7            4    10034  1317778395           1          4
# 2             9            8    20033  1988883321           0          1
#
#                    Emp_DOB             Emp_JoinDate  Emp_Active  City_Id  \
# 0  1978-05-12 00:00:00.000  2012-03-22 00:00:00.000           1        4
# 2  1982-08-20 00:00:00.000  2006-10-01 00:00:00.000           1        8
#
#    State_Id City_Name
# 0         4     Berat
# 2         8   Amsthas

# %%
Q16
Em_Ct_Dsg = pd.merge((pd.merge(Employee_Details, Country, how = 'left', left_on='Emp_Country_Id', right_on = 'Country_Id')),
                                      Designation, how = 'left', left_on='Design_Id', right_on = 'Design_Id')
Em_Ct_Dsg[(Em_Ct_Dsg.Emp_DOB > '19800101') & (Em_Ct_Dsg.Emp_DOB < '19900101')]
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 1       2         Joshua             NaN           Kan
# 2       3        Yuriana             NaN      Hagasawa
# 3       4        Venessa         Cameron      Katarina
# 5       6           Chen             NaN          Chen
#
#                 Emp_Address1                 Emp_Address2  Emp_Country_Id  \
# 1           533 Kosher Drive                          NaN              11
# 2             122 Kobeya Ave                          NaN               9
# 3  1001 Michigan Ave Apt3201                          NaN              11
# 5    55 Beijing Road Apt1501  230 Sanjiangkou Road Apt202               4
#
#    Emp_State_Id  Emp_City_Id  Emp_Zip  Emp_Mobile  Emp_Gender  Design_Id  \
# 1            34           54     3115  8553432022           1          2
# 2            21           27    84430  6644227722           0          1
# 3            28           38     1101  8572222210           0          6
# ...

# %%
Q17
Em_Ct_Dsg_Sal = pd.merge((pd.merge((pd.merge(Employee_Details, Country, how = 'left', left_on='Emp_Country_Id', right_on = 'Country_Id')),
                                      Designation, how = 'left', left_on='Design_Id', right_on = 'Design_Id')), 
                     Salary, how = 'left', left_on='Emp_Id', right_on = 'Emp_Id')
Slice = Em_Ct_Dsg_Sal.loc[:, ['Emp_First_Name', 'Emp_Last_Name', 'Emp_Middle_Name', 'Country_Name', 'Design_Name', 'Emp_Salary']]
Slice.loc[Slice.Emp_Salary.argmax()]
# Out:
# Emp_First_Name      Venessa
# Emp_Last_Name      Katarina
# Emp_Middle_Name     Cameron
# Country_Name        Denmark
# Design_Name             NaN
# Emp_Salary           185000
# Name: 9, dtype: object

# %%
Q18
Em_Ct_Dsg_Sal = pd.merge((pd.merge((pd.merge(Employee_Details, Country, how = 'left', left_on='Emp_Country_Id', right_on = 'Country_Id')),
                                      Designation, how = 'left', left_on='Design_Id', right_on = 'Design_Id')), 
                     Salary, how = 'left', left_on='Emp_Id', right_on = 'Emp_Id')
Em_Ct_Dsg_Sal.loc[:, ['Emp_First_Name', 'Emp_Last_Name', 'Emp_Middle_Name', 'Country_Name', 'Design_Name', 'Emp_Salary']]
# Out:
#    Emp_First_Name Emp_Last_Name Emp_Middle_Name Country_Name  Design_Name  \
# 0         Ronaldo     Fabrizzio            Rome      Albania          NaN
# 1         Ronaldo     Fabrizzio            Rome      Albania          NaN
# 2         Ronaldo     Fabrizzio            Rome      Albania          NaN
# 3          Joshua           Kan  Not Applicable      Denmark          NaN
# 4          Joshua           Kan  Not Applicable      Denmark          NaN
# 5          Joshua           Kan  Not Applicable      Denmark          NaN
# 6         Yuriana      Hagasawa  Not Applicable        China          NaN
# 7         Yuriana      Hagasawa  Not Applicable        China          NaN
# 8         Venessa      Katarina         Cameron      Denmark          NaN
# 9         Venessa      Katarina         Cameron      Denmark          NaN
# 10           Sahi          King  Not Applicable      Denmark          NaN
# 11           Sahi          King  Not Applicable      Denmark          NaN
# ...

# %%
Q19
Em_Ct_Dsg_Sal = pd.merge((pd.merge((pd.merge(Employee_Details, Country, how = 'left', left_on='Emp_Country_Id', right_on = 'Country_Id')),
                                      Designation, how = 'left', left_on='Design_Id', right_on = 'Design_Id')), 
                     Salary, how = 'left', left_on='Emp_Id', right_on = 'Emp_Id')
Em_Ct_Dsg_Sal[(Em_Ct_Dsg_Sal.Emp_Salary >= 50000.00) & (Em_Ct_Dsg_Sal.Emp_Salary <= 100000.00)]
#Em_Ct_Dsg_Sal_range.loc[:, ['Emp_First_Name', 'Emp_Last_Name', 'Emp_Middle_Name', 'Country_Name', 'Design_Name', 'Emp_Salary']]
# Out:
#     Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 0        1        Ronaldo            Rome     Fabrizzio
# 1        1        Ronaldo            Rome     Fabrizzio
# 2        1        Ronaldo            Rome     Fabrizzio
# 5        2         Joshua  Not Applicable           Kan
# 7        3        Yuriana  Not Applicable      Hagasawa
# 10       5           Sahi  Not Applicable          King
# 11       5           Sahi  Not Applicable          King
# 14       6           Chen  Not Applicable          Chen
# 15       6           Chen  Not Applicable          Chen
#
#                Emp_Address1                 Emp_Address2  Emp_Country_Id  \
# 0           75 Calle Suerte                          NaN               2
# 1           75 Calle Suerte                          NaN               2
# 2           75 Calle Suerte                          NaN               2
# 5          533 Kosher Drive                          NaN              11
# ...

# %%
Q20
Employee_Details.Emp_First_Name.str.slice( 0, 3)
# Out:
# 0    Ron
# 1    Jos
# 2    Yur
# 3    Ven
# 4    Sah
# 5    Che
# 6    Ric
# Name: Emp_First_Name, dtype: object

# %%
Q21
Employee_Details.Emp_First_Name.str.replace('a', '$')
# Out:
# 0    Ron$ldo
# 1     Joshu$
# 2    Yuri$n$
# 3    Veness$
# 4       S$hi
# 5       Chen
# 6      Ricky
# Name: Emp_First_Name, dtype: object

# %%
Q22
Employee_Details.Emp_JoinDate = pd.to_datetime(Employee_Details.Emp_JoinDate)
print(Employee_Details.Emp_First_Name)
print(Employee_Details.Emp_JoinDate.dt.year)
print(Employee_Details.Emp_JoinDate.dt.month)
print(Employee_Details.Emp_JoinDate.dt.day)
# Out:
# 0    Ronaldo
# 1     Joshua
# 2    Yuriana
# 3    Venessa
# 4       Sahi
# 5       Chen
# 6      Ricky
# Name: Emp_First_Name, dtype: object
# 0    2012
# 1    2010
# 2    2013
# 3    2009
# 4    1999
# 5    2006
# 6    2014
# Name: Emp_JoinDate, dtype: int64
# 0     3
# 1     1
# 2     9
# 3     2
# 4     3
# 5    10
# 6     5
# Name: Emp_JoinDate, dtype: int64
# 0    22
# 1    27
# 2     1
# 3     1
# 4     1
# 5     1
# 6     1
# Name: Emp_JoinDate, dtype: int64

# %%
Q23
Employee_Details.Emp_JoinDate = pd.to_datetime(Employee_Details.Emp_JoinDate)
Employee_Details[Employee_Details.Emp_JoinDate.dt.year == 2014]
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 6   10002          Ricky          Russel     Riverland
#
#                    Emp_Address1 Emp_Address2  Emp_Country_Id  Emp_State_Id  \
# 6  1019 Commonwealth Ave Apt301          NaN              11            29
#
#    Emp_City_Id  Emp_Zip  Emp_Mobile  Emp_Gender  Design_Id  \
# 6           39     2215  8572223333           1          3
#
#                    Emp_DOB Emp_JoinDate  Emp_Active
# 6  1993-01-01 00:00:00.000   2014-05-01           1

# %%
Q24
Employee_Details.Emp_JoinDate = pd.to_datetime(Employee_Details.Emp_JoinDate)
Employee_Details[Employee_Details.Emp_JoinDate.dt.year < 2014]
# Out:
#    Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 0       1        Ronaldo            Rome     Fabrizzio
# 1       2         Joshua  Not Applicable           Kan
# 2       3        Yuriana  Not Applicable      Hagasawa
# 3       4        Venessa         Cameron      Katarina
# 4       5           Sahi  Not Applicable          King
# 5       6           Chen  Not Applicable          Chen
#
#                 Emp_Address1                 Emp_Address2  Emp_Country_Id  \
# 0            75 Calle Suerte                          NaN               2
# 1           533 Kosher Drive                          NaN              11
# 2             122 Kobeya Ave                          NaN               9
# 3  1001 Michigan Ave Apt3201                          NaN              11
# 4       15 Gibbs Street Apt1                          NaN              11
# 5    55 Beijing Road Apt1501  230 Sanjiangkou Road Apt202               4
#
# ...

# %%
Q25
Em_Dsg_Sal = pd.merge((pd.merge(Employee_Details, Designation, how = 'left', left_on='Design_Id', right_on = 'Design_Id')), 
                     Salary, how = 'left', left_on='Emp_Id', right_on = 'Emp_Id')
Em_Dsg_Sal_Grp = Em_Dsg_Sal.groupby('Designation').sum()
Em_Dsg_Sal_Grp.loc[:, ['Emp_Salary'] ]
# Out:
#                     Emp_Salary
# Designation
# Business Analyst      225000.0
# Design Engineer       439200.0
# Project Manager       227000.0
# Software Developer    165000.0
# Team Leader                NaN
# Tech Lead             290000.0

# %%
Q26
Em_Dsg_Sal = pd.merge((pd.merge(Employee_Details, Designation, how = 'left', left_on='Design_Id', right_on = 'Design_Id')), 
                     Salary, how = 'left', left_on='Emp_Id', right_on = 'Emp_Id')
Em_Dsg_Sal_Grp = Em_Dsg_Sal.groupby('Designation').count()
Em_Dsg_Sal_Grp.loc[:, 'Emp_Id']
# Out:
# Designation
# Business Analyst      3
# Design Engineer       4
# Project Manager       4
# Software Developer    3
# Team Leader           1
# Tech Lead             2
# Name: Emp_Id, dtype: int64

# %%
Q27
Em_Dsg_Sal = pd.merge((pd.merge(Employee_Details, Designation, how = 'left', left_on='Design_Id', right_on = 'Design_Id')), 
                     Salary, how = 'left', left_on='Emp_Id', right_on = 'Emp_Id')
Em_Dsg_Sal_Grp = Em_Dsg_Sal.groupby('Designation').mean()
Em_Dsg_Sal_Grp.loc[:, 'Emp_Salary']
# Out:
# Designation
# Business Analyst       75000.0
# Design Engineer       109800.0
# Project Manager        56750.0
# Software Developer     55000.0
# Team Leader                NaN
# Tech Lead             145000.0
# Name: Emp_Salary, dtype: float64

# %%
Q28
Em_Sal = pd.merge(Employee_Details, Salary, how = 'left', left_on='Emp_Id', right_on = 'Emp_Id')
Em_Sal_only = Em_Sal.loc [:, ['Emp_First_Name', 'Emp_Salary']]
Em_Sal_only.groupby(['Emp_First_Name']).sum()
# Out:
#                 Emp_Salary
# Emp_First_Name
# Chen              143000.0
# Joshua            165000.0
# Ricky                  NaN
# Ronaldo           225000.0
# Sahi              439200.0
# Venessa           290000.0
# Yuriana            84000.0

# %%
Q29
Em_Sal = pd.merge(Employee_Details, Salary, how = 'left', left_on='Emp_Id', right_on = 'Emp_Id')
Em_Sal[Em_Sal.Emp_Salary.isnull()]
# Out:
#     Emp_Id Emp_First_Name Emp_Middle_Name Emp_Last_Name  \
# 16   10002          Ricky          Russel     Riverland
#
#                     Emp_Address1 Emp_Address2  Emp_Country_Id  Emp_State_Id  \
# 16  1019 Commonwealth Ave Apt301          NaN              11            29
#
#     Emp_City_Id  Emp_Zip  Emp_Mobile  Emp_Gender  Design_Id  \
# 16           39     2215  8572223333           1          3
#
#                     Emp_DOB Emp_JoinDate  Emp_Active  Salary_Id  \
# 16  1993-01-01 00:00:00.000   2014-05-01           1        NaN
#
#    Emp_Salary_Change_Year  Emp_Salary
# 16                    NaN         NaN

# %% [raw]
# Q34
# Em_Sal = pd.merge(Employee_Details, Salary, how = 'left', left_on='Emp_Id', right_on = 'Emp_Id')
# Em_Sal_only = Em_Sal.loc [:, ['Emp_First_Name', 'Emp_Salary']]
# Em_Sal_Sort = Em_Sal_only.sort_values(by = 'Emp_Salary', ascending = False)
# Em_Sal_Sort_ix = Em_Sal_Sort.ix
# Em_Sal_Sort_ix.iloc[2,:]

# %%
Q35
def func(X):
    print(X.groupby(['Emp_First_Name']).mean())
    
Em_Sal = pd.merge(Employee_Details, Salary, how = 'left', left_on='Emp_Id', right_on = 'Emp_Id')
Em_Sal_only = Em_Sal.loc [:, ['Emp_First_Name', 'Emp_Salary']]
func(Em_Sal_only)
# Out:
#                 Emp_Salary
# Emp_First_Name
# Chen               71500.0
# Joshua             55000.0
# Ricky                  NaN
# Ronaldo            75000.0
# Sahi              109800.0
# Venessa           145000.0
# Yuriana            42000.0
